# %% [markdown]
# # Object-centric analysis and flattening distortion
#
# Build an object-centric event representation containing orders, items, shipments, and invoices. Compare what happens when the same events are flattened by different object types.

# %%
from pathlib import Path
import sys
root = Path.cwd()
while not (root / 'labs').exists() and root != root.parent:
    root = root.parent
sys.path.insert(0, str(root))
from labs.common import load_module, load_variant_lab
lab = load_module('object_centric_lab', root / 'labs/06-object-centric-analysis/object_centric_lab.py')
events = load_variant_lab().generate_event_log()
summary, (oc_events, objects, event_objects, relations) = lab.compare_flattening(events)
display(summary)
display(objects.groupby('object_type').size().rename('objects'))
# Out:
#   case_notion  cases  rows  unique_events  duplication_factor  \
# 0       order    240  1129           1129            1.000000
# 1        item    352  1289            871            1.479908
# 2    shipment    120   255            255            1.000000
#
#    median_trace_length
# 0                  4.0
# 1                  3.0
# 2                  2.0
# object_type
# invoice     240
# item        352
# order       240
# shipment    120
# Name: objects, dtype: int64

# %%
display(relations.head(12))
display(event_objects.head(12))
shared = event_objects.groupby('event_id').size().sort_values(ascending=False)
display(shared.head(10).rename('related_objects'))
# Out:
#       source    target     relation
# 0     O-0001  I-0001-1     contains
# 1     O-0001  I-0001-2     contains
# 2   I-0001-1    S-0001   shipped_in
# 3   I-0001-2    S-0001   shipped_in
# 4     O-0001    V-0001  invoiced_by
# 5     O-0002  I-0002-1     contains
# 6   I-0002-1    S-0001   shipped_in
# 7     O-0002    V-0002  invoiced_by
# 8     O-0003  I-0003-1     contains
# 9     O-0003  I-0003-2     contains
# 10  I-0003-1    S-0002   shipped_in
# 11  I-0003-2    S-0002   shipped_in
#      event_id object_id
# 0   E-0001-01    O-0001
# 1   E-0001-02    O-0001
# 2   E-0001-02  I-0001-1
# 3   E-0001-02  I-0001-2
# 4   E-0001-03    O-0001
# 5   E-0001-03  I-0001-1
# 6   E-0001-03  I-0001-2
# 7   E-0001-03    V-0001
# 8   E-0001-04    O-0001
# 9   E-0001-04    S-0001
# 10  E-0001-04  I-0001-1
# 11  E-0001-04  I-0001-2
# event_id
# E-0096-05    5
# E-0101-04    5
# E-0231-03    5
# E-0101-03    5
# E-0056-05    5
# E-0056-04    5
# E-0056-03    5
# E-0011-03    5
# E-0011-04    5
# E-0011-05    5
# Name: related_objects, dtype: int64

# %% [markdown]
# ## Representation decision
#
# Choose a case notion for delivery performance and another for item-level rework. Explain convergence, divergence, duplicated event counts, and when the object-centric representation should be retained.

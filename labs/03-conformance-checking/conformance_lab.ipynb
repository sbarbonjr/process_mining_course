# %% [markdown]
# # Conformance checking with alignment diagnostics
#
# Compare observed traces with a small normative reference set. Alignment cost summarizes deviation, while individual moves explain what differed.

# %%
from pathlib import Path
import sys
root = Path.cwd()
while not (root / 'labs').exists() and root != root.parent:
    root = root.parent
sys.path.insert(0, str(root))
from labs.common import load_module, load_variant_lab
lab = load_module('conformance_lab', root / 'labs/03-conformance-checking/conformance_lab.py')
events = load_variant_lab().generate_event_log()
cases, deviations = lab.conformance_report(events)
display(cases.sort_values('alignment_cost', ascending=False).head(12))
display(deviations.head(12))
# Out:
#     case_id                                              trace  \
# 189  C-0190  Receive > Check > Approve > Rework > Approve >...
# 23   C-0024  Receive > Check > Approve > Rework > Approve >...
# 151  C-0152  Receive > Check > Approve > Rework > Approve >...
# 30   C-0031  Receive > Check > Approve > Rework > Approve >...
# 218  C-0219  Receive > Check > Approve > Rework > Approve >...
# 39   C-0040  Receive > Check > Approve > Rework > Approve >...
# 113  C-0114  Receive > Check > Approve > Rework > Approve >...
# 157  C-0158  Receive > Check > Approve > Rework > Approve >...
# 158  C-0159  Receive > Check > Approve > Rework > Approve >...
# 54   C-0055  Receive > Check > Approve > Rework > Approve >...
# 56   C-0057  Receive > Check > Approve > Rework > Approve >...
# 167  C-0168  Receive > Check > Approve > Rework > Approve >...
#
#                             reference  alignment_cost  conformance  \
# 189  Receive > Check > Approve > Ship               2     0.666667
# 23   Receive > Check > Approve > Ship               2     0.666667
# 151  Receive > Check > Approve > Ship               2     0.666667
# 30   Receive > Check > Approve > Ship               2     0.666667
# 218  Receive > Check > Approve > Ship               2     0.666667
# 39   Receive > Check > Approve > Ship               2     0.666667
# 113  Receive > Check > Approve > Ship               2     0.666667
# 157  Receive > Check > Approve > Ship               2     0.666667
# 158  Receive > Check > Approve > Ship               2     0.666667
# 54   Receive > Check > Approve > Ship               2     0.666667
# 56   Receive > Check > Approve > Ship               2     0.666667
# 167  Receive > Check > Approve > Ship               2     0.666667
#
#      deviation_moves
# 189                2
# 23                 2
# 151                2
# 30                 2
# 218                2
# 39                 2
# 113                2
# 157                2
# 158                2
# 54                 2
# 56                 2
# 167                2
#   move observed expected  count
# 0  log     Pack        -     33
# 1  log   Rework        -     27
# 2  log  Approve        -     27

# %%
example = tuple(cases.sort_values('alignment_cost', ascending=False).iloc[0]['trace'].split(' > '))
cost, reference, moves = lab.best_alignment(example)
print('Observed:', example)
print('Reference:', reference)
print('Cost:', cost)
display(moves)
# Out:
# Observed: ('Receive', 'Check', 'Approve', 'Rework', 'Approve', 'Ship')
# Reference: ('Receive', 'Check', 'Approve', 'Ship')
# Cost: 2
# [('sync', 'Receive', 'Receive'),
#  ('sync', 'Check', 'Check'),
#  ('sync', 'Approve', 'Approve'),
#  ('log', 'Rework', None),
#  ('log', 'Approve', None),
#  ('sync', 'Ship', 'Ship')]

# %% [markdown]
# ## Interpretation exercise
#
# Separate deviations that indicate non-compliance from deviations caused by an incomplete or overly strict reference model. Which moves require domain validation before escalation?
